# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

# %%
from typing import Dict, List, Optional

from smolagents import tools
import pandas as pd
import numpy as np

from src.agent.adapters.tools.base import BaseTool

# %%
## monkey patching

tools.AUTHORIZED_TYPES = [
    "string",
    "boolean",
    "integer",
    "number",
    "image",
    "audio",
    "array",
    "object",
    "any",
    "null",
    "list",
    "dict",
]

# %%
class GetData(BaseTool):
    name = "get_data"
    description = """Get data from an asset."""
    inputs = {
        "asset_ids": {"type": "list", "description": "list of asset ids"},
        "start_date": {"type": "string", "description": "start date", "nullable": True},
        "end_date": {"type": "string", "description": "end date", "nullable": True},
        "aggregation": {
            "type": "string",
            "description": "data aggregation",
            "nullable": True,
            "allowed": ["day", "minute", "hour"],
        },
        "last_value": {
            "type": "boolean",
            "description": "last value",
            "nullable": True,
        },
    }
    outputs = {"data": {"type": "dataframe", "description": "sensor data of an asset"}}
    output_type = "dict"

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def forward(
        self,
        asset_ids: List[str],
        start_date: Optional[str] = None,
        end_date: Optional[str] = None,
        aggregation: Optional[str] = "day",
        last_value: bool = False,
    ) -> Dict[str, List[str]]:
        df = pd.DataFrame()

        asset_ids = self.format_input(asset_ids)

        if not last_value:
            aggregation = self.map_aggregation(aggregation.lower())
            start_date = self.convert_to_iso_format(start_date)
            end_date = self.convert_to_iso_format(end_date)

        body = {
            "last_value": last_value,
            "start_date": start_date,
            "end_date": end_date,
            "aggregation": aggregation,
        }

        for asset_id in asset_ids:
            api_url = f"{self.base_url}/v1/data/{asset_id}"

            out = self.call_api(api_url, body=body)

            if out:
                _df = pd.DataFrame.from_dict(out)
                _df.set_index("timestamp", inplace=True)
                _df.drop(["pk_id", "asset_id"], inplace=True, axis=1)
                _df.columns = [asset_id]

                df = pd.merge(df, _df, left_index=True, right_index=True, how="outer")

        df.replace(np.nan, None, inplace=True)
        df.sort_index(inplace=True)

        return {"data": df}

    def map_aggregation(self, aggregation: str) -> str:
        """
        Map the aggregation to the correct aggregation type.
        """
        if aggregation not in ["day", "hour", "minute", "d", "h", "min"]:
            raise ValueError(
                f"Invalid aggregation: {aggregation} - only day, hour, minute, d, h, min are allowed"
            )

        if aggregation == "day" or aggregation == "d":
            aggregation = "d"
        elif aggregation == "hour" or aggregation == "h":
            aggregation = "h"
        elif aggregation == "minute" or aggregation == "min":
            aggregation = "min"
        else:
            aggregation = "d"

        return aggregation

# %%
kwargs = {"base_url": "http://localhost:5050"}

# %%
tool = GetData(**kwargs)

# %%
ids = [
    "a1ff2d3a-6fa9-492a-af51-cfd579cb2308",
    "52f50206-c6b9-47a4-bead-fe791f71cb7c",
    "9b71065a-2273-4173-9785-2487d1573dd7",
]

# %%
out = tool.forward(
    ids,
    start_date="2025-04-01T00:00:00",
    end_date="2025-04-01T23:59:00",
    aggregation="min",
)
# Out:
# 2025-05-13 10:17:38.703 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 0, 'limit': 100}
# 2025-05-13 10:17:39.546 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 100, 'limit': 100}
# 2025-05-13 10:17:40.011 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 200, 'limit': 100}
# 2025-05-13 10:17:40.472 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 300, 'limit': 100}
# 2025-05-13 10:17:40.913 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 400, 'limit': 100}
# 2025-05-13 10:17:41.377 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 500, 'limit': 100}
# 2025-05-13 10:17:41.868 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 600, 'limit': 100}
# 2025-05-13 10:17:42.314 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 700, 'limit': 100}
# 2025-05-13 10:17:42.761 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 800, 'limit': 100}
# 2025-05-13 10:17:43.210 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 900, 'limit': 100}
# 2025-05-13 10:17:43.658 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1000, 'limit': 100}
# 2025-05-13 10:17:44.126 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1100, 'limit': 100}
# 2025-05-13 10:17:44.582 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1200, 'limit': 100}
# 2025-05-13 10:17:45.044 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1300, 'limit': 100}
# 2025-05-13 10:17:45.503 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1400, 'limit': 100}
# 2025-05-13 10:17:45.963 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:17:45.979 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/9b71065a-2273-4173-9785-2487d1573dd7 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 0, 'limit': 100}
# 2025-05-13 10:17:46.423 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:17:46.424 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 0, 'limit': 100}
# 2025-05-13 10:17:46.881 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 100, 'limit': 100}
# 2025-05-13 10:17:47.355 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 200, 'limit': 100}
# 2025-05-13 10:17:47.821 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 300, 'limit': 100}
# 2025-05-13 10:17:48.279 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 400, 'limit': 100}
# 2025-05-13 10:17:48.732 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 500, 'limit': 100}
# 2025-05-13 10:17:49.215 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 600, 'limit': 100}
# 2025-05-13 10:17:49.665 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 700, 'limit': 100}
# 2025-05-13 10:17:50.116 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 800, 'limit': 100}
# 2025-05-13 10:17:50.575 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 900, 'limit': 100}
# 2025-05-13 10:17:51.038 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1000, 'limit': 100}
# 2025-05-13 10:17:51.492 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1100, 'limit': 100}
# 2025-05-13 10:17:51.946 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1200, 'limit': 100}
# 2025-05-13 10:17:52.394 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1300, 'limit': 100}
# 2025-05-13 10:17:52.847 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'min', 'offset': 1400, 'limit': 100}
# 2025-05-13 10:17:53.322 | INFO     | base:call_api:83 - Reached the last page.

# %%
# out["data"].to_csv("temp.csv", index=False)

# %%
out = tool.forward(
    ids,
    start_date="2025-04-01T00:00:00",
    end_date="2025-04-01T23:59:00",
    aggregation="h",
)
# Out:
# 2025-05-13 10:18:20.793 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'h', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:20.855 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:18:20.857 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/9b71065a-2273-4173-9785-2487d1573dd7 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'h', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:20.905 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:18:20.905 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'h', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:20.946 | INFO     | base:call_api:83 - Reached the last page.

# %%
out["data"]
# Out:
#                      52f50206-c6b9-47a4-bead-fe791f71cb7c  \
# timestamp
# 2025-04-01T00:00:00                                   1.0
# 2025-04-01T01:00:00                                   1.0
# 2025-04-01T02:00:00                                   1.0
# 2025-04-01T03:00:00                                   1.0
# 2025-04-01T04:00:00                                   1.0
# 2025-04-01T05:00:00                                   1.0
# 2025-04-01T06:00:00                                   1.0
# 2025-04-01T07:00:00                                   1.0
# 2025-04-01T08:00:00                                   1.0
# 2025-04-01T09:00:00                                   1.0
# 2025-04-01T10:00:00                                   1.0
# 2025-04-01T11:00:00                                   1.0
# 2025-04-01T12:00:00                                   1.0
# 2025-04-01T13:00:00                                   1.0
# 2025-04-01T14:00:00                                   1.0
# 2025-04-01T15:00:00                                   1.0
# 2025-04-01T16:00:00                                   1.0
# 2025-04-01T17:00:00                                   1.0
# 2025-04-01T18:00:00                                   1.0
# 2025-04-01T19:00:00                                   1.0
# 2025-04-01T20:00:00                                   1.0
# 2025-04-01T21:00:00                                   1.0
# 2025-04-01T22:00:00                                   1.0
# 2025-04-01T23:00:00                                   1.0
#
#                      a1ff2d3a-6fa9-492a-af51-cfd579cb2308
# timestamp
# 2025-04-01T00:00:00                              6.827667
# 2025-04-01T01:00:00                              6.899667
# 2025-04-01T02:00:00                              7.311667
# 2025-04-01T03:00:00                              7.403333
# 2025-04-01T04:00:00                              7.182833
# 2025-04-01T05:00:00                              7.019667
# 2025-04-01T06:00:00                              7.065333
# 2025-04-01T07:00:00                              6.290333
# 2025-04-01T08:00:00                              6.831333
# 2025-04-01T09:00:00                              6.963000
# 2025-04-01T10:00:00                              6.944167
# 2025-04-01T11:00:00                              6.894333
# 2025-04-01T12:00:00                              7.277000
# 2025-04-01T13:00:00                              6.446833
# 2025-04-01T14:00:00                              7.028833
# 2025-04-01T15:00:00                              7.143000
# 2025-04-01T16:00:00                              7.578500
# 2025-04-01T17:00:00                              7.274833
# 2025-04-01T18:00:00                              7.258000
# 2025-04-01T19:00:00                              7.530167
# 2025-04-01T20:00:00                              7.350833
# 2025-04-01T21:00:00                              6.198833
# 2025-04-01T22:00:00                              7.434667
# 2025-04-01T23:00:00                              6.712000

# %%
out = tool.forward(
    ids,
    start_date="2025-04-01T00:00:00",
    end_date="2025-04-01T23:59:00",
    aggregation="d",
)
# Out:
# 2025-05-13 10:18:29.126 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'd', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:29.175 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:18:29.176 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/9b71065a-2273-4173-9785-2487d1573dd7 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'd', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:29.198 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:18:29.198 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'd', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:29.234 | INFO     | base:call_api:83 - Reached the last page.

# %%
out["data"]
# Out:
#                      52f50206-c6b9-47a4-bead-fe791f71cb7c  \
# timestamp
# 2025-04-01T00:00:00                                   1.0
#
#                      a1ff2d3a-6fa9-492a-af51-cfd579cb2308
# timestamp
# 2025-04-01T00:00:00                              7.036118

# %%
ids = [
    None,
    "12",
    12,
    "PA101",
    "a1ff2d3a-6fa9-492a-af51-cfd579cb2308",
    "52f50206-c6b9-47a4-bead-fe791f71cb7c",
    "9b71065a-2273-4173-9785-2487d1573dd7",
]

# %%
out = tool.forward(ids, last_value=True)
# Out:
# 2025-05-13 10:18:34.033 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/a1ff2d3a-6fa9-492a-af51-cfd579cb2308 with params: {'last_value': True, 'start_date': None, 'end_date': None, 'aggregation': 'day', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:34.401 | INFO     | base:call_api:83 - Reached the last page.
# 2025-05-13 10:18:34.405 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/12 with params: {'last_value': True, 'start_date': None, 'end_date': None, 'aggregation': 'day', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:34.439 | DEBUG    | base:call_api:90 - HTTP error fetching name for http://localhost:5050/v1/data/12: 422 - {"detail":[{"type":"uuid_parsing","loc":["path","asset_id"],"msg":"Input should be a valid UUID, invalid length: expected length 32 for simple format, found 2","input":"12","ctx":{"error":"invalid length: expected length 32 for simple format, found 2"}}]}
# 2025-05-13 10:18:34.440 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/PA101 with params: {'last_value': True, 'start_date': None, 'end_date': None, 'aggregation': 'day', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:34.458 | DEBUG    | base:call_api:90 - HTTP error fetching name for http://localhost:5050/v1/data/PA101: 422 - {"detail":[{"type":"uuid_parsing","loc":["path","asset_id"],"msg":"Input should be a valid UUID, invalid character: expected an optional prefix of `urn:uuid:` followed by [0-9a-fA-F-], found `P` at 1","input":"PA101","ctx":{"error":"invalid character: expected an optional prefix of `urn:uuid:` followed by [0-9a-fA-F-], found `P` at 1"}}]}
# 2025-05-13 10:18:34.459 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/9b71065a-2273-4173-9785-2487d1573dd7 with params: {'last_value': True, 'start_date': None, 'end_date': None, 'aggregation': 'day', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:34.791 | DEBUG    | base:call_api:90 - HTTP error fetching name for http://localhost:5050/v1/data/9b71065a-2273-4173-9785-2487d1573dd7: 404 - {"detail":"No data found for asset_id 9b71065a-2273-4173-9785-2487d1573dd7"}
# 2025-05-13 10:18:34.791 | INFO     | base:call_api:71 - Fetching data from http://localhost:5050/v1/data/52f50206-c6b9-47a4-bead-fe791f71cb7c with params: {'last_value': True, 'start_date': None, 'end_date': None, 'aggregation': 'day', 'offset': 0, 'limit': 100}
# 2025-05-13 10:18:35.123 | INFO     | base:call_api:83 - Reached the last page.

# %%
out["data"]
# Out:
#                      a1ff2d3a-6fa9-492a-af51-cfd579cb2308  \
# timestamp
# 2025-12-31T23:59:00                                   0.0
#
#                      52f50206-c6b9-47a4-bead-fe791f71cb7c
# timestamp
# 2025-12-31T23:59:00                                   1.0

# %%
ids = ["84200101-d718-45bf-bfae-529513586ddd", "18b04353-839d-40a1-84c1-9b547d09dd80"]

# %%
out = tool.forward(
    ids[0],
    start_date="2025-04-01T00:00:00",
    end_date="2025-04-01T23:59:00",
    aggregation="h",
)
out2 = tool.forward(
    ids[1],
    start_date="2025-04-01T00:00:00",
    end_date="2025-04-01T23:59:00",
    aggregation="h",
)
# Out:
# 2025-05-13 21:31:44.183 | INFO     | src.agent.adapters.tools.base:call_api:74 - Fetching data from http://localhost:5050/v1/data/84200101-d718-45bf-bfae-529513586ddd with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'h', 'offset': 0, 'limit': 100}
# 2025-05-13 21:31:44.252 | INFO     | src.agent.adapters.tools.base:call_api:88 - Reached the last page.
# 2025-05-13 21:31:44.254 | INFO     | src.agent.adapters.tools.base:call_api:74 - Fetching data from http://localhost:5050/v1/data/18b04353-839d-40a1-84c1-9b547d09dd80 with params: {'last_value': False, 'start_date': '2025-04-01T00:00:00', 'end_date': '2025-04-01T23:59:00', 'aggregation': 'h', 'offset': 0, 'limit': 100}
# 2025-05-13 21:31:44.295 | INFO     | src.agent.adapters.tools.base:call_api:88 - Reached the last page.

# %%
# Out:
#                      84200101-d718-45bf-bfae-529513586ddd  \
# timestamp
# 2025-04-01T00:00:00                              3.049167
# 2025-04-01T01:00:00                              1.710667
# 2025-04-01T02:00:00                              2.032167
# 2025-04-01T03:00:00                              2.664500
# 2025-04-01T04:00:00                              2.351500
# 2025-04-01T05:00:00                              1.968167
# 2025-04-01T06:00:00                              1.796667
# 2025-04-01T07:00:00                              1.876000
# 2025-04-01T08:00:00                              1.761667
# 2025-04-01T09:00:00                              1.501333
# 2025-04-01T10:00:00                              1.966167
# 2025-04-01T11:00:00                              2.223667
# 2025-04-01T12:00:00                              2.151833
# 2025-04-01T13:00:00                              1.507500
# 2025-04-01T14:00:00                              2.181167
# 2025-04-01T15:00:00                              1.739500
# 2025-04-01T16:00:00                              2.340833
# 2025-04-01T17:00:00                              2.260833
# 2025-04-01T18:00:00                              2.578000
# 2025-04-01T19:00:00                              2.070500
# 2025-04-01T20:00:00                              1.790667
# 2025-04-01T21:00:00                              1.743667
# 2025-04-01T22:00:00                              2.338833
# 2025-04-01T23:00:00                              2.255833
#
#                      18b04353-839d-40a1-84c1-9b547d09dd80
# timestamp
# 2025-04-01T00:00:00                              1.615167
# 2025-04-01T01:00:00                              1.746167
# 2025-04-01T02:00:00                              1.511000
# 2025-04-01T03:00:00                              1.356500
# 2025-04-01T04:00:00                              1.099000
# 2025-04-01T05:00:00                              1.725500
# 2025-04-01T06:00:00                              1.248333
# 2025-04-01T07:00:00                              1.684333
# 2025-04-01T08:00:00                              1.817000
# 2025-04-01T09:00:00                              1.889167
# 2025-04-01T10:00:00                              1.767167
# 2025-04-01T11:00:00                              1.474167
# 2025-04-01T12:00:00                              1.297667
# 2025-04-01T13:00:00                              0.993167
# 2025-04-01T14:00:00                              1.955500
# 2025-04-01T15:00:00                              1.988667
# 2025-04-01T16:00:00                              2.135500
# 2025-04-01T17:00:00                              1.198000
# 2025-04-01T18:00:00                              1.550500
# 2025-04-01T19:00:00                              1.718833
# 2025-04-01T20:00:00                              1.841500
# 2025-04-01T21:00:00                              1.440667
# 2025-04-01T22:00:00                              1.070167
# 2025-04-01T23:00:00                              2.009667
